# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
path = pd.read_csv(r"C:\Users\Aaron\Downloads\archive1\videos-stats.csv")

# %%
df1 = pd.DataFrame(path)
df1
# Out:
#       Unnamed: 0                                              Title  \
# 0              0  Apple Pay Is Killing the Physical Wallet After...
# 1              1                    The most EXPENSIVE thing I own.
# 2              2                 My New House Gaming Setup is SICK!
# 3              3  Petrol Vs Liquid Nitrogen | Freezing Experimen...
# 4              4                     Best Back to School Tech 2022!
# ...          ...                                                ...
# 1876        1876                 Should You Learn Machine Learning?
# 1877        1877            Todos podemos aprender Machine learning
# 1878        1878  Andrew Ng: Deep Learning, Education, and Real-...
# 1879        1879                          What is Machine Learning?
# 1880        1880                   Don&#39;t learn machine learning
#
#          Video ID Published At           Keyword    Likes  Comments      Views
# ...

# %%
df1.shape
# Out:
# (1881, 8)

# %%
df1.describe()
# Out:
#         Unnamed: 0         Likes       Comments         Views
# count  1881.000000  1.879000e+03    1879.000000  1.879000e+03
# mean    940.000000  1.700610e+05    7863.331559  1.161292e+07
# std     543.142247  7.962293e+05   37879.964926  1.084450e+08
# min       0.000000 -1.000000e+00      -1.000000  2.500000e+01
# 25%     470.000000  2.672500e+03     199.000000  8.451500e+04
# 50%     940.000000  1.478700e+04     814.000000  5.917210e+05
# 75%    1410.000000  6.090600e+04    3377.500000  2.804978e+06
# max    1880.000000  1.644556e+07  732818.000000  4.034122e+09

# %%
df3 = df1.groupby(['Keyword'], as_index=False).agg({'Views':'median'})
df3 = df3.sort_values(by = 'Views',ascending = False)
df3
# Out:
#              Keyword       Views
# 28           mrbeast  65074742.5
# 3                bed   9359070.5
# 10             cubes   5038323.0
# 0            animals   4466776.0
# 39          tutorial   2817913.5
# 17            google   2530836.0
# 14              food   2456819.0
# 19            how-to   2023665.5
# 36            sports   1945140.0
# 4            biology   1743151.0
# 25     mathchemistry   1503148.0
# 24            marvel   1373022.5
# 33           physics   1299208.5
# 27            movies   1293718.0
# 20         interview   1152823.0
# 18           history    985739.5
# 37              tech    974911.5
# 29           mukbang    906361.0
# 5           business    633103.5
# 38          trolling    611040.0
# 12         education    575543.0
# 21        literature    557735.0
# 23  machine learning    512182.0
# 7                cnn    474328.5
# 22              lofi    461467.0
# 8   computer science    405950.5
# 15  game development    319505.0
# ...

# %%
sns.set(rc={"figure.figsize":(50, 4)})
ax = sns.barplot(x="Keyword", y="Views", data=df3)

# %%
df4 = df1.groupby(['Keyword'], as_index=False).agg({'Likes':'median'})
df4 = df4.sort_values(by = 'Likes',ascending = False)
df4
# Out:
#              Keyword      Likes
# 28           mrbeast  1687158.5
# 3                bed   133140.0
# 10             cubes    88548.5
# 39          tutorial    74692.5
# 19            how-to    52437.5
# 17            google    51098.0
# 14              food    47811.5
# 4            biology    44755.0
# 24            marvel    39104.0
# 25     mathchemistry    37430.0
# 37              tech    34664.0
# 33           physics    28674.0
# 0            animals    27982.5
# 38          trolling    25211.0
# 29           mukbang    24014.0
# 36            sports    22288.0
# 20         interview    21168.0
# 12         education    14402.0
# 5           business    14164.5
# 18           history    13404.5
# 8   computer science    13205.0
# 23  machine learning    12914.0
# 15  game development    12127.5
# 21        literature    10700.5
# 26         minecraft    10154.5
# 35               sat     8860.0
# 22              lofi     8031.0
# 27            movies     7791.0
# ...

# %%
ax1 = sns.barplot(x="Keyword", y="Likes", data=df4)

# %%
df5 = df1.groupby(['Keyword'], as_index=False).agg({'Comments':'median'})
df5 = df5.sort_values(by = 'Comments',ascending = False)
df5
# Out:
#              Keyword  Comments
# 28           mrbeast   66500.0
# 7                cnn    6447.0
# 3                bed    3712.0
# 17            google    3070.0
# 4            biology    2220.0
# 14              food    2119.5
# 24            marvel    2032.0
# 39          tutorial    2019.5
# 19            how-to    1970.0
# 37              tech    1861.0
# 10             cubes    1771.0
# 25     mathchemistry    1681.0
# 20         interview    1652.5
# 33           physics    1592.5
# 18           history    1270.5
# 0            animals    1144.0
# 36            sports    1116.0
# 38          trolling    1043.0
# 32          nintendo     860.0
# 12         education     823.5
# 31              news     793.0
# 29           mukbang     780.0
# 8   computer science     765.5
# 5           business     642.0
# 15  game development     569.0
# 35               sat     554.0
# 26         minecraft     446.5
# 1              apple     436.0
# 21        literature     415.5
# ...

# %%
ax3 = sns.barplot(x="Keyword", y="Comments", data=df5)
